# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import f1_score, accuracy_score, make_scorer


import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Exploratory Data Analysis

# %%
path = '~/Chase_Project/default of credit card clients.xls'
data = pd.read_excel(path, skiprows=1)
print(data.columns)
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
data.head(10)
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
# 5   6      50000    1          1         2   37      0      0      0      0
# 6   7     500000    1          1         2   29      0      0      0      0
# 7   8     100000    2          2         2   23      0     -1     -1      0
# 8   9     140000    2          3         1   28      0      0      2      0
# 9  10      20000    1          3         2   35     -2     -2     -2     -2
#
#               ...              BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# ...

# %%
data.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
# Rename columns
data = data.rename(columns={'PAY_0': 'PAY_1', 'default payment next month': 'DEF_PAY'})

# %%
# Examine categorical variables
data[['SEX', 'EDUCATION', 'MARRIAGE']].describe()
# Out:
#                 SEX     EDUCATION      MARRIAGE
# count  30000.000000  30000.000000  30000.000000
# mean       1.603733      1.853133      1.551867
# std        0.489129      0.790349      0.521970
# min        1.000000      0.000000      0.000000
# 25%        1.000000      1.000000      1.000000
# 50%        2.000000      2.000000      2.000000
# 75%        2.000000      2.000000      2.000000
# max        2.000000      6.000000      3.000000

# %%
arr = ['SEX', 'EDUCATION', 'MARRIAGE']

for i in arr:
    sns.countplot(data[i])
    plt.show()

# %% [markdown]
# It appears there are 30,000 clients and no missing data in this dataset. However, some of the category labels are undocumented such as Marriage code 0 and Education codes 5 and 6.

# %%
# Classify undocumented labels as Other: Marital status = 3, Education = 4
fil = (data.EDUCATION == 5) | (data.EDUCATION == 6) 
data.loc[fil, 'EDUCATION'] = 4
fil = (data.MARRIAGE == 0)
data.loc[fil, 'MARRIAGE'] = 3

sns.countplot(data['EDUCATION'])
plt.show()

# %%
sns.countplot(data['MARRIAGE'])
plt.show()

# %%
# Repayment Status
data[['PAY_1', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6']].describe()
# Out:
#               PAY_1         PAY_2         PAY_3         PAY_4         PAY_5  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      -0.016700     -0.133767     -0.166200     -0.220667     -0.266200
# std        1.123802      1.197186      1.196868      1.169139      1.133187
# min       -2.000000     -2.000000     -2.000000     -2.000000     -2.000000
# 25%       -1.000000     -1.000000     -1.000000     -1.000000     -1.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        8.000000      8.000000      8.000000      8.000000      8.000000
#
#               PAY_6
# count  30000.000000
# mean      -0.291100
# std        1.149988
# min       -2.000000
# 25%       -1.000000
# 50%        0.000000
# 75%        0.000000
# max        8.000000

# %%
arr = ['PAY_1', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6']

for i in arr:
    sns.countplot(data[i])
    plt.show()

# %%
# Bill Amounts
data[['BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6']].describe()
# Out:
#            BILL_AMT1      BILL_AMT2     BILL_AMT3      BILL_AMT4  \
# count   30000.000000   30000.000000  3.000000e+04   30000.000000
# mean    51223.330900   49179.075167  4.701315e+04   43262.948967
# std     73635.860576   71173.768783  6.934939e+04   64332.856134
# min   -165580.000000  -69777.000000 -1.572640e+05 -170000.000000
# 25%      3558.750000    2984.750000  2.666250e+03    2326.750000
# 50%     22381.500000   21200.000000  2.008850e+04   19052.000000
# 75%     67091.000000   64006.250000  6.016475e+04   54506.000000
# max    964511.000000  983931.000000  1.664089e+06  891586.000000
#
#            BILL_AMT5      BILL_AMT6
# count   30000.000000   30000.000000
# mean    40311.400967   38871.760400
# std     60797.155770   59554.107537
# min    -81334.000000 -339603.000000
# 25%      1763.000000    1256.000000
# 50%     18104.500000   17071.000000
# 75%     50190.500000   49198.250000
# max    927171.000000  961664.000000

# %%
# Previous Payments
data[['PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6']].describe()
# Out:
#             PAY_AMT1      PAY_AMT2      PAY_AMT3       PAY_AMT4  \
# count   30000.000000  3.000000e+04   30000.00000   30000.000000
# mean     5663.580500  5.921163e+03    5225.68150    4826.076867
# std     16563.280354  2.304087e+04   17606.96147   15666.159744
# min         0.000000  0.000000e+00       0.00000       0.000000
# 25%      1000.000000  8.330000e+02     390.00000     296.000000
# 50%      2100.000000  2.009000e+03    1800.00000    1500.000000
# 75%      5006.000000  5.000000e+03    4505.00000    4013.250000
# max    873552.000000  1.684259e+06  896040.00000  621000.000000
#
#             PAY_AMT5       PAY_AMT6
# count   30000.000000   30000.000000
# mean     4799.387633    5215.502567
# std     15278.305679   17777.465775
# min         0.000000       0.000000
# 25%       252.500000     117.750000
# 50%      1500.000000    1500.000000
# 75%      4031.500000    4000.000000
# max    426529.000000  528666.000000

# %%
# Amount of given credit
data.LIMIT_BAL.describe()
# Out:
# count      30000.000000
# mean      167484.322667
# std       129747.661567
# min        10000.000000
# 25%        50000.000000
# 50%       140000.000000
# 75%       240000.000000
# max      1000000.000000
# Name: LIMIT_BAL, dtype: float64

# %%
# Density plots
cols = [ f for f in data.columns if data.dtypes[ f ] != "object"]
cols.remove( "ID")
cols.remove('DEF_PAY')

f = pd.melt( data, id_vars='DEF_PAY', value_vars=cols)
g = sns.FacetGrid( f, hue='DEF_PAY', col="variable", col_wrap=5, sharex=False, sharey=False )
g = g.map( sns.distplot, "value", kde=True).add_legend()

# %% [markdown]
# Can see in the distribution of the top left graph that the default rate is much higher on lower balance limits.

# %%
sns.distplot(data['LIMIT_BAL'],kde=True,bins=200, color="blue")
plt.show()
data['LIMIT_BAL'].value_counts().head(5)
# Out:
# 50000     3365
# 20000     1976
# 30000     1610
# 80000     1567
# 200000    1528
# Name: LIMIT_BAL, dtype: int64

# %% [markdown]
# 50,000 is the most commonly issued credit limit.

# %% [markdown]
# ## Machine Learning

# %%
y = data['DEF_PAY'].copy()
y.sample(5)
# Out:
# 26090    0
# 4836     0
# 19828    0
# 26044    0
# 22483    0
# Name: DEF_PAY, dtype: int64

# %%
cols = ['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_1', 'PAY_2',
       'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
       'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
       'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6']
x = data[cols].copy()
x.columns
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_1', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6'],
#       dtype='object')

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=40)

# %%
#create classifier
classifier = DecisionTreeClassifier(max_depth=10, random_state=2020)

# train the classifier
classifier.fit(x_train, y_train)
predictions = classifier.predict(x_test)
f1_score(y_true = y_test, y_pred = predictions)
# Out:
# 0.48765803732691154

# %% [markdown]
# ### Hyperparameter Tuning with GridsearchCV

# %%
param_grid = {'max_depth': np.arange(3, 10),
             'criterion' : ['gini','entropy'],
             'max_leaf_nodes': [5,10,20,100],
             'min_samples_split': [2, 5, 10, 20],
             'class_weight' : ['balanced']}

grid_tree = GridSearchCV(DecisionTreeClassifier(), param_grid, cv = 5, scoring= 'f1') # use f1 score

#train
grid_tree.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, error_score='raise',
#        estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'max_depth': array([3, 4, 5, 6, 7, 8, 9]), 'criterion': ['gini', 'entropy'], 'max_leaf_nodes': [5, 10, 20, 100], 'min_samples_split': [2, 5, 10, 20], 'class_weight': ['balanced']},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='f1', verbose=0)

# %%
print(grid_tree.best_estimator_)
print(np.abs(grid_tree.best_score_))
# Out:
# DecisionTreeClassifier(class_weight='balanced', criterion='entropy',
#             max_depth=3, max_features=None, max_leaf_nodes=20,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# 0.522879445937793

# %%
# classifier with optimum parameters via gridsearchcv
classifier = DecisionTreeClassifier(class_weight='balanced', criterion='entropy',
            max_depth=3, max_features=None, max_leaf_nodes=20,
            min_impurity_decrease=0.0, min_impurity_split=None,
            min_samples_leaf=1, min_samples_split=2,
            min_weight_fraction_leaf=0.0, presort=False, random_state=None,
            splitter='best')
classifier.fit(x_train, y_train)
predictions = classifier.predict(x_test)
f1_score(y_true = y_test, y_pred = predictions)
# Out:
# 0.541282233262361

# %% [markdown]
# F1 Score is 0.541282233262361.
